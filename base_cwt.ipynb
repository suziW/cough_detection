# %% [markdown]
# # imports

# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf
from tensorflow.keras import layers
print(tf.__version__)
print(tf.test.is_gpu_available())

import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2.0.0
# True
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# # config

# %%
data_path = '/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform'
train_path = data_path + '/train/*/*'
test_path = data_path + '/test/*/*'
val_path = data_path + '/validation/*/*'

class_names = ['sick', 'not_sick']
img_height = 128#227
img_width = 128#227
batch_size = 4

# %% [markdown]
# # get dataset

# %%
def decode_str_tensor(tensor):
    return bytes.decode(tensor.numpy())

def stats(t):
    s = 'mean:'
    s += str(t.mean())
    s += ' max:'
    s += str(t.max())
    s += ' min:'
    s += str(t.min())
    s += ' median:'
    s += str(np.median(t))
    s += ' std:'
    s += str(t.std())
    s += ' shape:'
    s += str(t.shape)
    s += ' dtype:'
    s += str(t.dtype)
    print(s)

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    one_hot = parts[-2] == class_names
    one_hot = tf.cast(one_hot, tf.int64)
    # Integer encode the label
    return tf.argmax(one_hot)
get_label('/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform/train/sick/audioset_0CroKP1sYVw_10_15.jpg')
# Out:
# <tf.Tensor: id=67, shape=(), dtype=int64, numpy=0>

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)
    # resize the image to the desired size
    img = tf.image.resize(img, [img_height, img_width])
    img = img/255
    return img, label
img, label = process_path('/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform/train/sick/audioset_0CroKP1sYVw_10_15.jpg')
stats(img.numpy())
# Out:
# mean:0.1849789 max:1.0 min:0.0 median:0.003921569 std:0.25584865 shape:(128, 128, 3) dtype:float32

# %%
def get_dataset(path):
    ds = tf.data.Dataset.list_files(path)
    ds = ds.map(process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = ds.cache().shuffle(buffer_size=100).batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return ds

train_ds = get_dataset(train_path)
test_ds = get_dataset(test_path)
val_ds = get_dataset(val_path)
train_ds
# Out:
# <DatasetV1Adapter shapes: ((None, 128, 128, 3), (None,)), types: (tf.float32, tf.int64)>

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (4, 128, 128, 3)
# Label:  [1 0 0 0]

# %%
image_batch, label_batch = next(iter(val_ds))

plt.figure(figsize=(10, 10))
for i in range(4):
  ax = plt.subplot(2, 2, i + 1)
  plt.imshow((image_batch[i].numpy()*255).astype("uint8"))
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# # model

# %%
model = tf.keras.Sequential([
    layers.Input(shape=[img_height, img_width, 3]),
    
    layers.Conv2D(32, 3, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D(),
    
    layers.Conv2D(64, 3, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D(),
    
    layers.Conv2D(32, 3, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D(),
    
    layers.Flatten(),
    
    layers.Dropout(0.2),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    
    layers.Dense(1)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# re_lu (ReLU)                 (None, 128, 128, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                524352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 562,785
# Trainable params: 562,529
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# # train

# %%
model.compile(
  optimizer='adam',
  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 929/929 [==============================] - 9s 10ms/step - loss: 0.6542 - accuracy: 0.6475 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.5113 - accuracy: 0.7234 - val_loss: 0.4965 - val_accuracy: 0.6719
# Epoch 3/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.4841 - accuracy: 0.7357 - val_loss: 0.5468 - val_accuracy: 0.6399
# Epoch 4/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.4732 - accuracy: 0.7339 - val_loss: 0.4814 - val_accuracy: 0.7055
# Epoch 5/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.4494 - accuracy: 0.7594 - val_loss: 0.5225 - val_accuracy: 0.7432
# Epoch 6/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.4413 - accuracy: 0.7519 - val_loss: 0.4411 - val_accuracy: 0.7621
# Epoch 7/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.4097 - accuracy: 0.7750 - val_loss: 0.4645 - val_accuracy: 0.7309
# Epoch 8/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.3935 - accuracy: 0.7836 - val_loss: 0.4420 - val_accuracy: 0.7769
# Epoch 9/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.3574 - accuracy: 0.8049 - val_loss: 0.4935 - val_accuracy: 0.7900
# Epoch 10/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.3440 - accuracy: 0.8162 - val_loss: 0.4539 - val_accuracy: 0.7629
# Epoch 11/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.3055 - accuracy: 0.8313 - val_loss: 0.4717 - val_accuracy: 0.7449
# Epoch 12/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.2808 - accuracy: 0.8458 - val_loss: 0.5009 - val_accuracy: 0.7785
# Epoch 13/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.2632 - accuracy: 0.8644 - val_loss: 1.0678 - val_accuracy: 0.7088
# Epoch 14/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.2360 - accuracy: 0.8765 - val_loss: 1.0851 - val_accuracy: 0.7260
# Epoch 15/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.2191 - accuracy: 0.8875 - val_loss: 0.5652 - val_accuracy: 0.7818
# Epoch 16/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.2091 - accuracy: 0.8926 - val_loss: 0.6107 - val_accuracy: 0.7613
# Epoch 17/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.1945 - accuracy: 0.9010 - val_loss: 0.5632 - val_accuracy: 0.7785
# Epoch 18/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.1644 - accuracy: 0.9066 - val_loss: 1.5960 - val_accuracy: 0.7039
# Epoch 19/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.1635 - accuracy: 0.9131 - val_loss: 0.6924 - val_accuracy: 0.8015
# Epoch 20/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.1586 - accuracy: 0.9214 - val_loss: 0.6589 - val_accuracy: 0.7744
# Epoch 21/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.1360 - accuracy: 0.9354 - val_loss: 0.8107 - val_accuracy: 0.7629
# Epoch 22/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.1381 - accuracy: 0.9354 - val_loss: 0.8684 - val_accuracy: 0.7506
# Epoch 23/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.1257 - accuracy: 0.9403 - val_loss: 0.7827 - val_accuracy: 0.7711
# Epoch 24/30
# 929/929 [==============================] - 5s 6ms/step - loss: 0.1128 - accuracy: 0.9440 - val_loss: 0.7539 - val_accuracy: 0.7596
# Epoch 25/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.1127 - accuracy: 0.9429 - val_loss: 0.8226 - val_accuracy: 0.7884
# Epoch 26/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.1145 - accuracy: 0.9462 - val_loss: 1.3435 - val_accuracy: 0.7285
# Epoch 27/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.1145 - accuracy: 0.9435 - val_loss: 0.6724 - val_accuracy: 0.7892
# Epoch 28/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.1112 - accuracy: 0.9505 - val_loss: 0.9063 - val_accuracy: 0.7990
# Epoch 29/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.0947 - accuracy: 0.9540 - val_loss: 0.8993 - val_accuracy: 0.7990
# Epoch 30/30
# 929/929 [==============================] - 5s 5ms/step - loss: 0.1024 - accuracy: 0.9540 - val_loss: 4.6773 - val_accuracy: 0.6415

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(test_ds)
# Out:
# 413/413 [==============================] - 5s 13ms/step - loss: 4.6938 - accuracy: 0.6471
# [4.6938216455542605, 0.6470944]
