# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf
from tensorflow.keras import layers
print(tf.__version__)
print(tf.test.is_gpu_available())

import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2.0.0
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# True

# %% [markdown]
# # config

# %%
data_path = '/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform'
train_path = data_path + '/train/*/*'
test_path = data_path + '/test/*/*'
val_path = data_path + '/validation/*/*'

class_names = ['sick', 'not_sick']
img_height = 227#227
img_width = 227#227
batch_size = 4
train_samples = 1434 + 2282
steps_per_epoch = train_samples // batch_size
steps_per_epoch
# Out:
# 929

# %% [markdown]
# # get dataset

# %%
def decode_str_tensor(tensor):
    return bytes.decode(tensor.numpy())

def stats(t):
    s = 'mean:'
    s += str(t.mean())
    s += ' max:'
    s += str(t.max())
    s += ' min:'
    s += str(t.min())
    s += ' median:'
    s += str(np.median(t))
    s += ' std:'
    s += str(t.std())
    s += ' shape:'
    s += str(t.shape)
    s += ' dtype:'
    s += str(t.dtype)
    print(s)

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    one_hot = parts[-2] == class_names
    one_hot = tf.cast(one_hot, tf.int64)
    # Integer encode the label
    return tf.argmax(one_hot)
get_label('/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform/train/sick/audioset_0CroKP1sYVw_10_15.jpg')
# Out:
# <tf.Tensor: id=67, shape=(), dtype=int64, numpy=0>

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)
    # resize the image to the desired size
    img = tf.image.resize(img, [img_height, img_width])
#     img = img/127.5 - 1
    return img, label
img, label = process_path('/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform/train/sick/audioset_0CroKP1sYVw_10_15.jpg')
stats(img.numpy())
# Out:
# mean:47.180405 max:255.0 min:0.0 median:1.0 std:65.353775 shape:(227, 227, 3) dtype:float32

# %%
def get_dataset(path):
    ds = tf.data.Dataset.list_files(path)
    ds = ds.map(process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = ds.cache().shuffle(buffer_size=100).batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return ds

train_ds = get_dataset(train_path)
test_ds = get_dataset(test_path)
val_ds = get_dataset(val_path)
train_ds
# Out:
# <DatasetV1Adapter shapes: ((None, 227, 227, 3), (None,)), types: (tf.float32, tf.int64)>

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (4, 227, 227, 3)
# Label:  [1 1 1 1]

# %%
image_batch, label_batch = next(iter(val_ds))

plt.figure(figsize=(10, 10))
for i in range(4):
  ax = plt.subplot(2, 2, i + 1)
  plt.imshow((image_batch[i].numpy()).astype("uint8"))
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# # model

# %% [markdown]
# ### Feature extraction

# %%
IMG_SHAPE = (img_height, img_width, 3)
# base_model = tf.keras.applications.DenseNet121(include_top=False, 
#                                                weights='imagenet', 
#                                                input_shape=IMG_SHAPE
# )
base_model = tf.keras.applications.ResNet50(include_top=False, 
                                            weights='imagenet', 
                                            input_shape=IMG_SHAPE,
                                            classes=1)
base_model.trainable = False
base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 227, 227, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 233, 233, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 114, 114, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 114, 114, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 114, 114, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 116, 116, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 57, 57, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 57, 57, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 57, 57, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 57, 57, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 57, 57, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 57, 57, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 57, 57, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 57, 57, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 57, 57, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 57, 57, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 57, 57, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 57, 57, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 57, 57, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 57, 57, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 57, 57, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 57, 57, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 57, 57, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 57, 57, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 57, 57, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 57, 57, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 57, 57, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 57, 57, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 57, 57, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 57, 57, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 57, 57, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 57, 57, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 57, 57, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 57, 57, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 57, 57, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 57, 57, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 57, 57, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 57, 57, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 57, 57, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 29, 29, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 29, 29, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 29, 29, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 29, 29, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 29, 29, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 29, 29, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 29, 29, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 29, 29, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 29, 29, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 29, 29, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 29, 29, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 29, 29, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 29, 29, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 29, 29, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 29, 29, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 29, 29, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 29, 29, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 29, 29, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 29, 29, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 29, 29, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 29, 29, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 29, 29, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 29, 29, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 29, 29, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 29, 29, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 29, 29, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 29, 29, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 29, 29, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 29, 29, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 29, 29, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 29, 29, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 29, 29, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 29, 29, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 29, 29, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 29, 29, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 29, 29, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 29, 29, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 29, 29, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 29, 29, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 29, 29, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 29, 29, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 29, 29, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 15, 15, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 15, 15, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 15, 15, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 15, 15, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 15, 15, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 15, 15, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 15, 15, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 15, 15, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 15, 15, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 15, 15, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 15, 15, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 15, 15, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 15, 15, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 15, 15, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 15, 15, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 15, 15, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 15, 15, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 15, 15, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 15, 15, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 15, 15, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 15, 15, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 15, 15, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 15, 15, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 15, 15, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 15, 15, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 15, 15, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 15, 15, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 15, 15, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 15, 15, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 15, 15, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 15, 15, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 15, 15, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 15, 15, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 15, 15, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 15, 15, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 15, 15, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 15, 15, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 15, 15, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 15, 15, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 15, 15, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 15, 15, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 15, 15, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 15, 15, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 15, 15, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 15, 15, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 15, 15, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 15, 15, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 15, 15, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 15, 15, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 15, 15, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 15, 15, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 8, 8, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 8, 8, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 8, 8, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 8, 8, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 8, 8, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 8, 8, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 8, 8, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 8, 8, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 8, 8, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 8, 8, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 8, 8, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 8, 8, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 8, 8, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 8, 8, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 8, 8, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 8, 8, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
inputs = tf.keras.Input(shape=IMG_SHAPE)
x = tf.keras.applications.resnet.preprocess_input(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 227, 227, 3)]     0
# _________________________________________________________________
# resnet50 (Model)             (None, 8, 8, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 23,850,113
# Trainable params: 262,401
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
base_learning_rate = 0.0001
save_dir = './fine_tune_resnet50_cwt/'
log_dir = save_dir + 'logs/'
checkpoint_dir = save_dir + 'checkpoint_Feature_extraction/'

lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    base_learning_rate,
    decay_steps=steps_per_epoch*5,
    decay_rate=1,
    staircase=False)

optimizer = tf.keras.optimizers.Adam(lr_schedule)

callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10),
        tf.keras.callbacks.TensorBoard(log_dir),
        tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_dir,
                                            monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                            save_weights_only=True)
    ]

# %%
initial_epochs = 100

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_ds,
                    epochs=initial_epochs,
                    validation_data=val_ds,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
#     929/Unknown - 25s 27ms/step - loss: 2.2063 - accuracy: 0.6316
# Epoch 00001: val_accuracy improved from -inf to 0.66694, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 33s 36ms/step - loss: 2.2063 - accuracy: 0.6316 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 927/929 [============================>.] - ETA: 0s - loss: 1.4665 - accuracy: 0.6923
# Epoch 00002: val_accuracy improved from 0.66694 to 0.67760, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 29s 31ms/step - loss: 1.4663 - accuracy: 0.6924 - val_loss: 1.2710 - val_accuracy: 0.6776
# Epoch 3/100
# 927/929 [============================>.] - ETA: 0s - loss: 1.2086 - accuracy: 0.6936
# Epoch 00003: val_accuracy did not improve from 0.67760
# 929/929 [==============================] - 29s 31ms/step - loss: 1.2084 - accuracy: 0.6929 - val_loss: 1.0912 - val_accuracy: 0.6678
# Epoch 4/100
# 927/929 [============================>.] - ETA: 0s - loss: 1.0508 - accuracy: 0.7036
# Epoch 00004: val_accuracy improved from 0.67760 to 0.68909, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 29s 31ms/step - loss: 1.0508 - accuracy: 0.7029 - val_loss: 0.9676 - val_accuracy: 0.6891
# Epoch 5/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.9552 - accuracy: 0.7093
# Epoch 00005: val_accuracy improved from 0.68909 to 0.69647, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.9554 - accuracy: 0.7094 - val_loss: 0.8869 - val_accuracy: 0.6965
# Epoch 6/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.8898 - accuracy: 0.7122
# Epoch 00006: val_accuracy improved from 0.69647 to 0.69811, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 31ms/step - loss: 0.8903 - accuracy: 0.7118 - val_loss: 0.8379 - val_accuracy: 0.6981
# Epoch 7/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.8381 - accuracy: 0.7155
# Epoch 00007: val_accuracy improved from 0.69811 to 0.71124, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 30s 32ms/step - loss: 0.8381 - accuracy: 0.7156 - val_loss: 0.7857 - val_accuracy: 0.7112
# Epoch 8/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.7961 - accuracy: 0.7171
# Epoch 00008: val_accuracy improved from 0.71124 to 0.71370, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.7962 - accuracy: 0.7172 - val_loss: 0.7510 - val_accuracy: 0.7137
# Epoch 9/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.7698 - accuracy: 0.7225
# Epoch 00009: val_accuracy did not improve from 0.71370
# 929/929 [==============================] - 28s 30ms/step - loss: 0.7698 - accuracy: 0.7226 - val_loss: 0.7282 - val_accuracy: 0.7129
# Epoch 10/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.7545 - accuracy: 0.7119
# Epoch 00010: val_accuracy improved from 0.71370 to 0.72026, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.7544 - accuracy: 0.7118 - val_loss: 0.7096 - val_accuracy: 0.7203
# Epoch 11/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.7386 - accuracy: 0.7198
# Epoch 00011: val_accuracy improved from 0.72026 to 0.72354, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.7388 - accuracy: 0.7196 - val_loss: 0.6911 - val_accuracy: 0.7235
# Epoch 12/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.7187 - accuracy: 0.7217
# Epoch 00012: val_accuracy improved from 0.72354 to 0.73831, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.7183 - accuracy: 0.7220 - val_loss: 0.6765 - val_accuracy: 0.7383
# Epoch 13/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.7002 - accuracy: 0.7268
# Epoch 00013: val_accuracy did not improve from 0.73831
# 929/929 [==============================] - 28s 30ms/step - loss: 0.7002 - accuracy: 0.7271 - val_loss: 0.6614 - val_accuracy: 0.7383
# Epoch 14/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6943 - accuracy: 0.7336
# Epoch 00014: val_accuracy did not improve from 0.73831
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6943 - accuracy: 0.7339 - val_loss: 0.6514 - val_accuracy: 0.7367
# Epoch 15/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6744 - accuracy: 0.7352
# Epoch 00015: val_accuracy did not improve from 0.73831
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6742 - accuracy: 0.7357 - val_loss: 0.6472 - val_accuracy: 0.7326
# Epoch 16/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6765 - accuracy: 0.7260
# Epoch 00016: val_accuracy did not improve from 0.73831
# 929/929 [==============================] - 27s 30ms/step - loss: 0.6766 - accuracy: 0.7255 - val_loss: 0.6428 - val_accuracy: 0.7194
# Epoch 17/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6621 - accuracy: 0.7293
# Epoch 00017: val_accuracy did not improve from 0.73831
# 929/929 [==============================] - 27s 30ms/step - loss: 0.6621 - accuracy: 0.7290 - val_loss: 0.6313 - val_accuracy: 0.7358
# Epoch 18/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6580 - accuracy: 0.7295
# Epoch 00018: val_accuracy did not improve from 0.73831
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6580 - accuracy: 0.7295 - val_loss: 0.6238 - val_accuracy: 0.7375
# Epoch 19/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6521 - accuracy: 0.7300
# Epoch 00019: val_accuracy improved from 0.73831 to 0.73913, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6523 - accuracy: 0.7295 - val_loss: 0.6172 - val_accuracy: 0.7391
# Epoch 20/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6536 - accuracy: 0.7330
# Epoch 00020: val_accuracy did not improve from 0.73913
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6536 - accuracy: 0.7333 - val_loss: 0.6141 - val_accuracy: 0.7326
# Epoch 21/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6427 - accuracy: 0.7241
# Epoch 00021: val_accuracy did not improve from 0.73913
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6427 - accuracy: 0.7239 - val_loss: 0.6119 - val_accuracy: 0.7252
# Epoch 22/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6385 - accuracy: 0.7260
# Epoch 00022: val_accuracy did not improve from 0.73913
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6385 - accuracy: 0.7260 - val_loss: 0.6038 - val_accuracy: 0.7375
# Epoch 23/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.6353 - accuracy: 0.7349
# Epoch 00023: val_accuracy did not improve from 0.73913
# 929/929 [==============================] - 27s 29ms/step - loss: 0.6357 - accuracy: 0.7349 - val_loss: 0.6009 - val_accuracy: 0.7383
# Epoch 24/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6298 - accuracy: 0.7330
# Epoch 00024: val_accuracy improved from 0.73913 to 0.74323, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6298 - accuracy: 0.7330 - val_loss: 0.5979 - val_accuracy: 0.7432
# Epoch 25/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.6232 - accuracy: 0.7335
# Epoch 00025: val_accuracy did not improve from 0.74323
# 929/929 [==============================] - 27s 29ms/step - loss: 0.6235 - accuracy: 0.7330 - val_loss: 0.5913 - val_accuracy: 0.7416
# Epoch 26/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.6251 - accuracy: 0.7327
# Epoch 00026: val_accuracy did not improve from 0.74323
# 929/929 [==============================] - 27s 29ms/step - loss: 0.6247 - accuracy: 0.7330 - val_loss: 0.5914 - val_accuracy: 0.7383
# Epoch 27/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6254 - accuracy: 0.7241
# Epoch 00027: val_accuracy did not improve from 0.74323
# 929/929 [==============================] - 29s 31ms/step - loss: 0.6254 - accuracy: 0.7239 - val_loss: 0.5870 - val_accuracy: 0.7432
# Epoch 28/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6181 - accuracy: 0.7233
# Epoch 00028: val_accuracy did not improve from 0.74323
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6181 - accuracy: 0.7234 - val_loss: 0.5831 - val_accuracy: 0.7383
# Epoch 29/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6148 - accuracy: 0.7317
# Epoch 00029: val_accuracy did not improve from 0.74323
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6151 - accuracy: 0.7314 - val_loss: 0.5777 - val_accuracy: 0.7432
# Epoch 30/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5967 - accuracy: 0.7503
# Epoch 00030: val_accuracy improved from 0.74323 to 0.74979, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 29s 32ms/step - loss: 0.5967 - accuracy: 0.7505 - val_loss: 0.5709 - val_accuracy: 0.7498
# Epoch 31/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.6011 - accuracy: 0.7424
# Epoch 00031: val_accuracy improved from 0.74979 to 0.75390, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6010 - accuracy: 0.7427 - val_loss: 0.5678 - val_accuracy: 0.7539
# Epoch 32/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6089 - accuracy: 0.7341
# Epoch 00032: val_accuracy improved from 0.75390 to 0.75882, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 31ms/step - loss: 0.6086 - accuracy: 0.7344 - val_loss: 0.5675 - val_accuracy: 0.7588
# Epoch 33/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6080 - accuracy: 0.7368
# Epoch 00033: val_accuracy did not improve from 0.75882
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6084 - accuracy: 0.7365 - val_loss: 0.5660 - val_accuracy: 0.7514
# Epoch 34/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.6006 - accuracy: 0.7381
# Epoch 00034: val_accuracy improved from 0.75882 to 0.75964, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6004 - accuracy: 0.7382 - val_loss: 0.5625 - val_accuracy: 0.7596
# Epoch 35/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.6031 - accuracy: 0.7306
# Epoch 00035: val_accuracy did not improve from 0.75964
# 929/929 [==============================] - 27s 29ms/step - loss: 0.6024 - accuracy: 0.7312 - val_loss: 0.5641 - val_accuracy: 0.7473
# Epoch 36/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5972 - accuracy: 0.7266
# Epoch 00036: val_accuracy did not improve from 0.75964
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5972 - accuracy: 0.7266 - val_loss: 0.5619 - val_accuracy: 0.7555
# Epoch 37/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5963 - accuracy: 0.7360
# Epoch 00037: val_accuracy did not improve from 0.75964
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5962 - accuracy: 0.7360 - val_loss: 0.5619 - val_accuracy: 0.7465
# Epoch 38/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5918 - accuracy: 0.7384
# Epoch 00038: val_accuracy did not improve from 0.75964
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5918 - accuracy: 0.7387 - val_loss: 0.5574 - val_accuracy: 0.7564
# Epoch 39/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5969 - accuracy: 0.7363
# Epoch 00039: val_accuracy did not improve from 0.75964
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5969 - accuracy: 0.7363 - val_loss: 0.5572 - val_accuracy: 0.7465
# Epoch 40/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5916 - accuracy: 0.7376
# Epoch 00040: val_accuracy improved from 0.75964 to 0.76128, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 29s 31ms/step - loss: 0.5919 - accuracy: 0.7371 - val_loss: 0.5509 - val_accuracy: 0.7613
# Epoch 41/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5946 - accuracy: 0.7311
# Epoch 00041: val_accuracy improved from 0.76128 to 0.76210, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5942 - accuracy: 0.7314 - val_loss: 0.5523 - val_accuracy: 0.7621
# Epoch 42/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5826 - accuracy: 0.7403
# Epoch 00042: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5826 - accuracy: 0.7406 - val_loss: 0.5486 - val_accuracy: 0.7580
# Epoch 43/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5817 - accuracy: 0.7419
# Epoch 00043: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5816 - accuracy: 0.7411 - val_loss: 0.5453 - val_accuracy: 0.7539
# Epoch 44/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5878 - accuracy: 0.7349
# Epoch 00044: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5877 - accuracy: 0.7352 - val_loss: 0.5461 - val_accuracy: 0.7555
# Epoch 45/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5834 - accuracy: 0.7387
# Epoch 00045: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5834 - accuracy: 0.7390 - val_loss: 0.5450 - val_accuracy: 0.7596
# Epoch 46/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5764 - accuracy: 0.7406
# Epoch 00046: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5762 - accuracy: 0.7409 - val_loss: 0.5439 - val_accuracy: 0.7572
# Epoch 47/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5787 - accuracy: 0.7449
# Epoch 00047: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5787 - accuracy: 0.7452 - val_loss: 0.5426 - val_accuracy: 0.7605
# Epoch 48/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5763 - accuracy: 0.7414
# Epoch 00048: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5763 - accuracy: 0.7414 - val_loss: 0.5414 - val_accuracy: 0.7596
# Epoch 49/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5830 - accuracy: 0.7387
# Epoch 00049: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5829 - accuracy: 0.7387 - val_loss: 0.5410 - val_accuracy: 0.7613
# Epoch 50/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5816 - accuracy: 0.7387
# Epoch 00050: val_accuracy did not improve from 0.76210
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5816 - accuracy: 0.7384 - val_loss: 0.5415 - val_accuracy: 0.7572
# Epoch 51/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5665 - accuracy: 0.7446
# Epoch 00051: val_accuracy improved from 0.76210 to 0.76538, saving model to ./fine_tune_resnet50_cwt/checkpoint_Feature_extraction/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5665 - accuracy: 0.7446 - val_loss: 0.5372 - val_accuracy: 0.7654
# Epoch 52/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5747 - accuracy: 0.7406
# Epoch 00052: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5745 - accuracy: 0.7409 - val_loss: 0.5357 - val_accuracy: 0.7621
# Epoch 53/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5710 - accuracy: 0.7416
# Epoch 00053: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5715 - accuracy: 0.7419 - val_loss: 0.5349 - val_accuracy: 0.7629
# Epoch 54/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5695 - accuracy: 0.7430
# Epoch 00054: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5696 - accuracy: 0.7422 - val_loss: 0.5351 - val_accuracy: 0.7646
# Epoch 55/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5708 - accuracy: 0.7443
# Epoch 00055: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5711 - accuracy: 0.7443 - val_loss: 0.5349 - val_accuracy: 0.7596
# Epoch 56/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5682 - accuracy: 0.7387
# Epoch 00056: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5678 - accuracy: 0.7392 - val_loss: 0.5337 - val_accuracy: 0.7629
# Epoch 57/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5704 - accuracy: 0.7381
# Epoch 00057: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5700 - accuracy: 0.7382 - val_loss: 0.5317 - val_accuracy: 0.7646
# Epoch 58/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5697 - accuracy: 0.7368
# Epoch 00058: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5694 - accuracy: 0.7371 - val_loss: 0.5311 - val_accuracy: 0.7613
# Epoch 59/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5687 - accuracy: 0.7497
# Epoch 00059: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5687 - accuracy: 0.7500 - val_loss: 0.5305 - val_accuracy: 0.7646
# Epoch 60/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5630 - accuracy: 0.7425
# Epoch 00060: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5630 - accuracy: 0.7425 - val_loss: 0.5307 - val_accuracy: 0.7588
# Epoch 61/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5642 - accuracy: 0.7505
# Epoch 00061: val_accuracy did not improve from 0.76538
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5640 - accuracy: 0.7505 - val_loss: 0.5300 - val_accuracy: 0.7596

# %%
model.load_weights(checkpoint_dir)
model.evaluate(test_ds)
# Out:
# 413/413 [==============================] - 10s 25ms/step - loss: 0.5369 - accuracy: 0.7591
# [0.536855103533724, 0.7590799]

# %% [markdown]
# ### fine tuning

# %%
base_model.trainable = True
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 150

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False
# Out:
# Number of layers in the base model:  175

# %%
fine_tune_epochs = 100 + initial_epochs

checkpoint_dir = save_dir + 'checkpoint_fine-tuning/'
callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10),
        tf.keras.callbacks.TensorBoard(log_dir),
        tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_dir,
                                            monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                            save_weights_only=True)
    ]
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    base_learning_rate/10,
    decay_steps=steps_per_epoch*5,
    decay_rate=1,
    staircase=False)
optimizer = tf.keras.optimizers.Adam(lr_schedule)

model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = optimizer,
              metrics=['accuracy'])
model.summary()
history_fine = model.fit(train_ds,
                         epochs=fine_tune_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=val_ds,
                         callbacks=callbacks)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 227, 227, 3)]     0
# _________________________________________________________________
# resnet50 (Model)             (None, 8, 8, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 23,850,113
# Trainable params: 10,252,545
# Non-trainable params: 13,597,568
# _________________________________________________________________
# Epoch 61/200
#     929/Unknown - 33s 35ms/step - loss: 0.5398 - accuracy: 0.7718
# Epoch 00061: val_accuracy improved from -inf to 0.74405, saving model to ./fine_tune_resnet50_cwt/checkpoint_fine-tuning/
# 929/929 [==============================] - 41s 44ms/step - loss: 0.5398 - accuracy: 0.7718 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 62/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.4748 - accuracy: 0.7988
# Epoch 00062: val_accuracy improved from 0.74405 to 0.81788, saving model to ./fine_tune_resnet50_cwt/checkpoint_fine-tuning/
# 929/929 [==============================] - 37s 40ms/step - loss: 0.4749 - accuracy: 0.7987 - val_loss: 0.4669 - val_accuracy: 0.8179
# Epoch 63/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.4157 - accuracy: 0.8471
# Epoch 00063: val_accuracy improved from 0.81788 to 0.82363, saving model to ./fine_tune_resnet50_cwt/checkpoint_fine-tuning/
# 929/929 [==============================] - 37s 40ms/step - loss: 0.4155 - accuracy: 0.8474 - val_loss: 0.4656 - val_accuracy: 0.8236
# Epoch 64/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.3554 - accuracy: 0.8776
# Epoch 00064: val_accuracy improved from 0.82363 to 0.83511, saving model to ./fine_tune_resnet50_cwt/checkpoint_fine-tuning/
# 929/929 [==============================] - 36s 39ms/step - loss: 0.3552 - accuracy: 0.8778 - val_loss: 0.4762 - val_accuracy: 0.8351
# Epoch 65/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.3063 - accuracy: 0.9040
# Epoch 00065: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 36s 38ms/step - loss: 0.3061 - accuracy: 0.9042 - val_loss: 0.4906 - val_accuracy: 0.8343
# Epoch 66/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.2537 - accuracy: 0.9312
# Epoch 00066: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 35s 38ms/step - loss: 0.2535 - accuracy: 0.9314 - val_loss: 0.5755 - val_accuracy: 0.8089
# Epoch 67/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.2053 - accuracy: 0.9502
# Epoch 00067: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 36s 39ms/step - loss: 0.2053 - accuracy: 0.9499 - val_loss: 0.6463 - val_accuracy: 0.8179
# Epoch 68/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.1647 - accuracy: 0.9733
# Epoch 00068: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 36s 39ms/step - loss: 0.1646 - accuracy: 0.9734 - val_loss: 0.7349 - val_accuracy: 0.8253
# Epoch 69/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1459 - accuracy: 0.9760
# Epoch 00069: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 36s 39ms/step - loss: 0.1459 - accuracy: 0.9760 - val_loss: 0.7557 - val_accuracy: 0.8171
# Epoch 70/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1233 - accuracy: 0.9881
# Epoch 00070: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 36s 38ms/step - loss: 0.1233 - accuracy: 0.9882 - val_loss: 0.8760 - val_accuracy: 0.8203
# Epoch 71/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.1129 - accuracy: 0.9903
# Epoch 00071: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 37s 39ms/step - loss: 0.1129 - accuracy: 0.9903 - val_loss: 0.9195 - val_accuracy: 0.8228
# Epoch 72/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9943
# Epoch 00072: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 36s 39ms/step - loss: 0.1049 - accuracy: 0.9943 - val_loss: 1.0056 - val_accuracy: 0.8261
# Epoch 73/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0953 - accuracy: 0.9960
# Epoch 00073: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 37s 40ms/step - loss: 0.0953 - accuracy: 0.9960 - val_loss: 1.0040 - val_accuracy: 0.8195
# Epoch 74/200
# 927/929 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9949
# Epoch 00074: val_accuracy did not improve from 0.83511
# 929/929 [==============================] - 37s 40ms/step - loss: 0.0956 - accuracy: 0.9949 - val_loss: 1.0213 - val_accuracy: 0.8253

# %%
checkpoint_dir = save_dir + 'fine_tune_resnet50_cwt/'

model.load_weights(checkpoint_dir)
model.evaluate(test_ds)
# Out:
# 341/413 [=======================>......] - ETA: 1s - loss: 0.5389 - accuracy: 0.7603
