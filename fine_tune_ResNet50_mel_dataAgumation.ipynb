# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf
from tensorflow.keras import layers
print(tf.__version__)
print(tf.test.is_gpu_available())

import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2.0.0
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# True

# %% [markdown]
# # config

# %%
data_path = '/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/melspectrograms/melspectrograms'
train_path = data_path + '/train/*/*'
test_path = data_path + '/test/*/*'
val_path = data_path + '/validation/*/*'

class_names = ['sick', 'not_sick']
img_height = 480#227
img_width = 640#227
batch_size = 4
train_samples = 1434 + 2282
steps_per_epoch = train_samples // batch_size
steps_per_epoch
# Out:
# 929

# %% [markdown]
# # get dataset

# %%
def decode_str_tensor(tensor):
    return bytes.decode(tensor.numpy())

def stats(t):
    s = 'mean:'
    s += str(t.mean())
    s += ' max:'
    s += str(t.max())
    s += ' min:'
    s += str(t.min())
    s += ' median:'
    s += str(np.median(t))
    s += ' std:'
    s += str(t.std())
    s += ' shape:'
    s += str(t.shape)
    s += ' dtype:'
    s += str(t.dtype)
    print(s)

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    one_hot = parts[-2] == class_names
    one_hot = tf.cast(one_hot, tf.int64)
    # Integer encode the label
    return tf.argmax(one_hot)
# get_label('/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform/train/sick/audioset_0CroKP1sYVw_10_15.jpg')

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)
    # resize the image to the desired size
    img = tf.image.resize(img, [img_height, img_width])        
    return img, label
# img, label = process_path('/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform/train/sick/audioset_0CroKP1sYVw_10_15.jpg')
# stats(img.numpy())

# %%
def augumation(img, label):
    if tf.random.uniform(()) > 0.33:
        rand = tf.cast(tf.random.uniform(())*img_width, tf.int64)
        x1, x2 = tf.split(img, [rand, img_width-rand], axis=1)
        img = tf.concat([x2, x1], axis=1)
#         tf.print(x1.shape, img.shape)
    img = tf.image.resize(img, [img_height, img_width])
    return img, label

# %%
def get_dataset(path, name, isaugumation=False):
    ds = tf.data.Dataset.list_files(path)
    ds = ds.map(process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = ds.cache(name).shuffle(buffer_size=100)
    if isaugumation:
        ds = ds.map(augumation, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = ds.batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return ds

train_ds = get_dataset(train_path, 'train_catch', True)
test_ds = get_dataset(test_path, 'test_catch')
val_ds = get_dataset(val_path, 'val_catch')
train_ds
# Out:
# <DatasetV1Adapter shapes: ((None, 480, 640, 3), (None,)), types: (tf.float32, tf.int64)>

# %%
for image, label in train_ds.take(5):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (4, 480, 640, 3)
# Label:  [0 0 1 0]
# Image shape:  (4, 480, 640, 3)
# Label:  [1 1 1 1]
# Image shape:  (4, 480, 640, 3)
# Label:  [0 1 1 1]
# Image shape:  (4, 480, 640, 3)
# Label:  [0 1 1 1]
# Image shape:  (4, 480, 640, 3)
# Label:  [1 1 1 1]

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(10, 10))
for i in range(4):
  ax = plt.subplot(2, 2, i + 1)
  stats(image_batch[i].numpy())
  plt.imshow((image_batch[i].numpy()).astype("uint8"))
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")
# Out:
# mean:159.31003 max:255.0 min:0.0 median:181.0 std:100.65663 shape:(480, 640, 3) dtype:float32
# mean:147.77055 max:255.0 min:0.0 median:130.0 std:102.124405 shape:(480, 640, 3) dtype:float32
# mean:130.31343 max:255.0 min:0.0 median:117.0 std:110.12201 shape:(480, 640, 3) dtype:float32
# mean:122.4445 max:255.0 min:0.0 median:97.0 std:117.33953 shape:(480, 640, 3) dtype:float32

# %% [markdown]
# # model

# %% [markdown]
# ### Feature extraction

# %%
IMG_SHAPE = (img_height, img_width, 3)
# base_model = tf.keras.applications.DenseNet201(include_top=False, 
#                                                weights='imagenet', 
#                                                input_shape=IMG_SHAPE,
#                                                classes=1)
# base_model = tf.keras.applications.DenseNet121(include_top=False, 
#                                                weights='imagenet', 
#                                                input_shape=IMG_SHAPE,
#                                                classes=1)
# )
base_model = tf.keras.applications.ResNet50(include_top=False, 
                                            weights='imagenet', 
                                            input_shape=IMG_SHAPE,
                                            classes=1)
# base_model = tf.keras.applications.Xception(include_top=False, 
#                                 weights='imagenet', 
#                                 input_shape=IMG_SHAPE,
#                                 classes=1)
base_model.trainable = False
base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 480, 640, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 486, 646, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 240, 320, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 240, 320, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 240, 320, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 242, 322, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 120, 160, 64) 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 120, 160, 64) 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 120, 160, 64) 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 120, 160, 64) 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 120, 160, 64) 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 120, 160, 64) 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 120, 160, 64) 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 120, 160, 256 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 120, 160, 256 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 120, 160, 256 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 120, 160, 256 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 120, 160, 256 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 120, 160, 256 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 120, 160, 64) 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 120, 160, 64) 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 120, 160, 64) 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 120, 160, 64) 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 120, 160, 64) 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 120, 160, 64) 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 120, 160, 256 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 120, 160, 256 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 120, 160, 256 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 120, 160, 256 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 120, 160, 64) 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 120, 160, 64) 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 120, 160, 64) 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 120, 160, 64) 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 120, 160, 64) 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 120, 160, 64) 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 120, 160, 256 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 120, 160, 256 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 120, 160, 256 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 120, 160, 256 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 60, 80, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 60, 80, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 60, 80, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 60, 80, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 60, 80, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 60, 80, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 60, 80, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 60, 80, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 60, 80, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 60, 80, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 60, 80, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 60, 80, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 60, 80, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 60, 80, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 60, 80, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 60, 80, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 60, 80, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 60, 80, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 60, 80, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 60, 80, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 60, 80, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 60, 80, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 60, 80, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 60, 80, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 60, 80, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 60, 80, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 60, 80, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 60, 80, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 60, 80, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 60, 80, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 60, 80, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 60, 80, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 60, 80, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 60, 80, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 60, 80, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 30, 40, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 30, 40, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 30, 40, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 30, 40, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 30, 40, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 30, 40, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 30, 40, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 30, 40, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 30, 40, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 30, 40, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 30, 40, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 30, 40, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 30, 40, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 30, 40, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 30, 40, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 30, 40, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 30, 40, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 30, 40, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 30, 40, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 30, 40, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 30, 40, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 30, 40, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 30, 40, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 30, 40, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 30, 40, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 30, 40, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 30, 40, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 30, 40, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 30, 40, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 30, 40, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 30, 40, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 30, 40, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 30, 40, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 30, 40, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 30, 40, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 30, 40, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 30, 40, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 30, 40, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 30, 40, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 30, 40, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 30, 40, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 30, 40, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 30, 40, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 30, 40, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 30, 40, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 30, 40, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 30, 40, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 30, 40, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 30, 40, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 30, 40, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 30, 40, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 15, 20, 512)  524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 15, 20, 512)  2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 15, 20, 512)  0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 15, 20, 512)  2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 15, 20, 512)  2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 15, 20, 512)  0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 15, 20, 2048) 2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 15, 20, 2048) 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 15, 20, 2048) 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 15, 20, 2048) 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 15, 20, 2048) 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 15, 20, 2048) 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 15, 20, 512)  1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 15, 20, 512)  2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 15, 20, 512)  0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 15, 20, 512)  2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 15, 20, 512)  2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 15, 20, 512)  0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 15, 20, 2048) 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 15, 20, 2048) 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 15, 20, 2048) 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 15, 20, 2048) 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 15, 20, 512)  1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 15, 20, 512)  2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 15, 20, 512)  0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 15, 20, 512)  2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 15, 20, 512)  2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 15, 20, 512)  0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 15, 20, 2048) 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 15, 20, 2048) 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 15, 20, 2048) 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 15, 20, 2048) 0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
inputs = tf.keras.Input(shape=IMG_SHAPE)
x = tf.keras.applications.resnet.preprocess_input(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dropout(0.5)(x)
# x = layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 480, 640, 3)]     0
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 480, 640, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 480, 640, 3)]     0
# _________________________________________________________________
# resnet50 (Model)             (None, 15, 20, 2048)      23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 23,589,761
# Trainable params: 2,049
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
initial_epochs = 100

base_learning_rate = 0.0001
save_dir = './fine_tune_ResNet50_mel/'
log_dir = save_dir + 'logs/'
checkpoint_dir = save_dir + 'checkpoint_Feature_extraction/'

lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    base_learning_rate,
    decay_steps=steps_per_epoch*5,
    decay_rate=1,
    staircase=False)

optimizer = tf.keras.optimizers.Adam(lr_schedule)

callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=2),
#         tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3),
        tf.keras.callbacks.TensorBoard(log_dir),
        tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_dir,
                                            monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                            save_weights_only=True)
    ]

# %%
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_ds,
                    epochs=initial_epochs,
                    validation_data=val_ds,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
#       1/Unknown - 5s 5s/step - loss: 0.9875 - accuracy: 0.0000e+00WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.116564). Check your callbacks.
#     929/Unknown - 133s 143ms/step - loss: 0.7033 - accuracy: 0.5963
# Epoch 00001: val_accuracy improved from -inf to 0.71452, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 180s 193ms/step - loss: 0.7033 - accuracy: 0.5963 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6203 - accuracy: 0.6606
# Epoch 00002: val_accuracy improved from 0.71452 to 0.74979, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 176s 190ms/step - loss: 0.6203 - accuracy: 0.6601 - val_loss: 0.5302 - val_accuracy: 0.7498
# Epoch 3/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5884 - accuracy: 0.6773
# Epoch 00003: val_accuracy improved from 0.74979 to 0.75062, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 179s 193ms/step - loss: 0.5884 - accuracy: 0.6776 - val_loss: 0.5066 - val_accuracy: 0.7506
# Epoch 4/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5673 - accuracy: 0.6964
# Epoch 00004: val_accuracy improved from 0.75062 to 0.75144, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 179s 193ms/step - loss: 0.5673 - accuracy: 0.6964 - val_loss: 0.4933 - val_accuracy: 0.7514
# Epoch 5/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5436 - accuracy: 0.7107
# Epoch 00005: val_accuracy improved from 0.75144 to 0.75882, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 179s 192ms/step - loss: 0.5436 - accuracy: 0.7104 - val_loss: 0.4867 - val_accuracy: 0.7588
# Epoch 6/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5439 - accuracy: 0.7150
# Epoch 00006: val_accuracy improved from 0.75882 to 0.76046, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 179s 193ms/step - loss: 0.5439 - accuracy: 0.7145 - val_loss: 0.4795 - val_accuracy: 0.7605
# Epoch 7/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5458 - accuracy: 0.7085
# Epoch 00007: val_accuracy improved from 0.76046 to 0.76292, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 178s 192ms/step - loss: 0.5458 - accuracy: 0.7086 - val_loss: 0.4765 - val_accuracy: 0.7629
# Epoch 8/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5312 - accuracy: 0.7271
# Epoch 00008: val_accuracy improved from 0.76292 to 0.76866, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 179s 193ms/step - loss: 0.5312 - accuracy: 0.7269 - val_loss: 0.4733 - val_accuracy: 0.7687
# Epoch 9/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5262 - accuracy: 0.7249
# Epoch 00009: val_accuracy improved from 0.76866 to 0.77194, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 180s 193ms/step - loss: 0.5262 - accuracy: 0.7250 - val_loss: 0.4701 - val_accuracy: 0.7719
# Epoch 10/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5174 - accuracy: 0.7328
# Epoch 00010: val_accuracy improved from 0.77194 to 0.77358, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 180s 193ms/step - loss: 0.5174 - accuracy: 0.7328 - val_loss: 0.4684 - val_accuracy: 0.7736
# Epoch 11/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5217 - accuracy: 0.7311
# Epoch 00011: val_accuracy improved from 0.77358 to 0.77441, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 179s 193ms/step - loss: 0.5217 - accuracy: 0.7314 - val_loss: 0.4645 - val_accuracy: 0.7744
# Epoch 12/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5092 - accuracy: 0.7414
# Epoch 00012: val_accuracy did not improve from 0.77441
# 929/929 [==============================] - 178s 192ms/step - loss: 0.5092 - accuracy: 0.7414 - val_loss: 0.4628 - val_accuracy: 0.7744
# Epoch 13/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5172 - accuracy: 0.7282
# Epoch 00013: val_accuracy improved from 0.77441 to 0.77851, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 179s 192ms/step - loss: 0.5172 - accuracy: 0.7279 - val_loss: 0.4623 - val_accuracy: 0.7785
# Epoch 14/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5192 - accuracy: 0.7239
# Epoch 00014: val_accuracy improved from 0.77851 to 0.78015, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 180s 193ms/step - loss: 0.5192 - accuracy: 0.7236 - val_loss: 0.4609 - val_accuracy: 0.7801
# Epoch 15/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5104 - accuracy: 0.7400
# Epoch 00015: val_accuracy improved from 0.78015 to 0.78589, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 179s 193ms/step - loss: 0.5104 - accuracy: 0.7400 - val_loss: 0.4603 - val_accuracy: 0.7859
# Epoch 16/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5062 - accuracy: 0.7395
# Epoch 00016: val_accuracy did not improve from 0.78589
# 929/929 [==============================] - 178s 192ms/step - loss: 0.5062 - accuracy: 0.7392 - val_loss: 0.4587 - val_accuracy: 0.7810
# Epoch 17/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5023 - accuracy: 0.7530
# Epoch 00017: val_accuracy improved from 0.78589 to 0.78835, saving model to ./fine_tune_ResNet50_mel/checkpoint_Feature_extraction/
# 929/929 [==============================] - 178s 191ms/step - loss: 0.5023 - accuracy: 0.7530 - val_loss: 0.4589 - val_accuracy: 0.7884
# Epoch 18/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.4980 - accuracy: 0.7513
# Epoch 00018: val_accuracy did not improve from 0.78835
# 929/929 [==============================] - 178s 192ms/step - loss: 0.4980 - accuracy: 0.7513 - val_loss: 0.4564 - val_accuracy: 0.7851
# Epoch 19/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5022 - accuracy: 0.7478
# Epoch 00019: val_accuracy did not improve from 0.78835
# 929/929 [==============================] - 177s 190ms/step - loss: 0.5022 - accuracy: 0.7478 - val_loss: 0.4564 - val_accuracy: 0.7851

# %%
model.load_weights(checkpoint_dir)
model.evaluate(test_ds)
# Out:
# 413/413 [==============================] - 63s 152ms/step - loss: 0.4734 - accuracy: 0.7730
# [0.473416921951003, 0.77300245]

# %% [markdown]
# ### fine tuning

# %%
base_model.trainable = True
print("Number of layers in the base model: ", len(base_model.layers))

# # Fine-tune from this layer onwards
# fine_tune_at = 100

# # Freeze all the layers before the `fine_tune_at` layer
# for layer in base_model.layers[:fine_tune_at]:
#     layer.trainable =  False
# Out:
# Number of layers in the base model:  175

# %%
fine_tune_epochs = 100 + initial_epochs

checkpoint_dir = save_dir + 'checkpoint_fine-tuning_dataAgumation/'
callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10),
        tf.keras.callbacks.TensorBoard(log_dir),
        tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_dir+'model-{epoch:02d}-{val_loss:.4f}-{val_accuracy:.4f}.h5',
                                            monitor='val_accuracy',
                                             verbose=1,
#                                              save_best_only=True,
                                            save_weights_only=True)
    ]
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    base_learning_rate/3,
    decay_steps=steps_per_epoch*5,
    decay_rate=1,
    staircase=False)
optimizer = tf.keras.optimizers.Adam(lr_schedule)

model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = optimizer,
              metrics=['accuracy'])
model.summary()
history_fine = model.fit(train_ds,
                         epochs=fine_tune_epochs,
#                          initial_epoch=history.epoch[-1],
                         validation_data=val_ds,
                         callbacks=callbacks)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 480, 640, 3)]     0
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 480, 640, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 480, 640, 3)]     0
# _________________________________________________________________
# resnet50 (Model)             (None, 15, 20, 2048)      23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 23,589,761
# Trainable params: 23,536,641
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/200
#     929/Unknown - 254s 273ms/step - loss: 0.5367 - accuracy: 0.7236
# Epoch 00001: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-01-0.4040-0.8318.h5
# 929/929 [==============================] - 301s 324ms/step - loss: 0.5367 - accuracy: 0.7236 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.4185 - accuracy: 0.8039
# Epoch 00002: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-02-0.4151-0.8269.h5
# 929/929 [==============================] - 296s 318ms/step - loss: 0.4185 - accuracy: 0.8038 - val_loss: 0.4151 - val_accuracy: 0.8269
# Epoch 3/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.3410 - accuracy: 0.8489
# Epoch 00003: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-03-0.5450-0.8507.h5
# 929/929 [==============================] - 296s 318ms/step - loss: 0.3410 - accuracy: 0.8490 - val_loss: 0.5450 - val_accuracy: 0.8507
# Epoch 4/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.3076 - accuracy: 0.8712
# Epoch 00004: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-04-0.2768-0.8950.h5
# 929/929 [==============================] - 296s 318ms/step - loss: 0.3076 - accuracy: 0.8714 - val_loss: 0.2768 - val_accuracy: 0.8950
# Epoch 5/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.2629 - accuracy: 0.8971
# Epoch 00005: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-05-0.3504-0.8811.h5
# 929/929 [==============================] - 297s 320ms/step - loss: 0.2629 - accuracy: 0.8972 - val_loss: 0.3504 - val_accuracy: 0.8811
# Epoch 6/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.2262 - accuracy: 0.9073
# Epoch 00006: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-06-0.3158-0.8999.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.2262 - accuracy: 0.9074 - val_loss: 0.3158 - val_accuracy: 0.8999
# Epoch 7/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1794 - accuracy: 0.9300
# Epoch 00007: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-07-0.3818-0.8753.h5
# 929/929 [==============================] - 299s 321ms/step - loss: 0.1794 - accuracy: 0.9298 - val_loss: 0.3818 - val_accuracy: 0.8753
# Epoch 8/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1435 - accuracy: 0.9491
# Epoch 00008: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-08-0.3721-0.8868.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.1435 - accuracy: 0.9491 - val_loss: 0.3721 - val_accuracy: 0.8868
# Epoch 9/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1225 - accuracy: 0.9547
# Epoch 00009: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-09-0.3807-0.8901.h5
# 929/929 [==============================] - 297s 320ms/step - loss: 0.1225 - accuracy: 0.9548 - val_loss: 0.3807 - val_accuracy: 0.8901
# Epoch 10/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1021 - accuracy: 0.9669
# Epoch 00010: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-10-0.3979-0.8917.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.1021 - accuracy: 0.9669 - val_loss: 0.3979 - val_accuracy: 0.8917
# Epoch 11/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0858 - accuracy: 0.9723
# Epoch 00011: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-11-0.4507-0.8958.h5
# 929/929 [==============================] - 297s 319ms/step - loss: 0.0858 - accuracy: 0.9723 - val_loss: 0.4507 - val_accuracy: 0.8958
# Epoch 12/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0761 - accuracy: 0.9752
# Epoch 00012: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-12-0.5145-0.8925.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0761 - accuracy: 0.9752 - val_loss: 0.5145 - val_accuracy: 0.8925
# Epoch 13/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0681 - accuracy: 0.9776
# Epoch 00013: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-13-0.4712-0.8983.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0681 - accuracy: 0.9777 - val_loss: 0.4712 - val_accuracy: 0.8983
# Epoch 14/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9844
# Epoch 00014: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-14-0.5140-0.8901.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0536 - accuracy: 0.9844 - val_loss: 0.5140 - val_accuracy: 0.8901
# Epoch 15/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0502 - accuracy: 0.9849
# Epoch 00015: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-15-0.5045-0.9048.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0502 - accuracy: 0.9849 - val_loss: 0.5045 - val_accuracy: 0.9048
# Epoch 16/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.9892
# Epoch 00016: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-16-0.5768-0.9073.h5
# 929/929 [==============================] - 298s 321ms/step - loss: 0.0419 - accuracy: 0.9892 - val_loss: 0.5768 - val_accuracy: 0.9073
# Epoch 17/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9879
# Epoch 00017: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-17-0.4969-0.9007.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0507 - accuracy: 0.9879 - val_loss: 0.4969 - val_accuracy: 0.9007
# Epoch 18/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0473 - accuracy: 0.9879
# Epoch 00018: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-18-0.5758-0.8893.h5
# 929/929 [==============================] - 298s 321ms/step - loss: 0.0473 - accuracy: 0.9879 - val_loss: 0.5758 - val_accuracy: 0.8893
# Epoch 19/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9922
# Epoch 00019: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-19-0.4901-0.8917.h5
# 929/929 [==============================] - 297s 320ms/step - loss: 0.0341 - accuracy: 0.9922 - val_loss: 0.4901 - val_accuracy: 0.8917
# Epoch 20/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0377 - accuracy: 0.9895
# Epoch 00020: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-20-0.5550-0.8975.h5
# 929/929 [==============================] - 297s 319ms/step - loss: 0.0377 - accuracy: 0.9895 - val_loss: 0.5550 - val_accuracy: 0.8975
# Epoch 21/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 0.9949
# Epoch 00021: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-21-0.6627-0.8991.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0248 - accuracy: 0.9949 - val_loss: 0.6627 - val_accuracy: 0.8991
# Epoch 22/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9925
# Epoch 00022: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-22-0.7593-0.8917.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0289 - accuracy: 0.9925 - val_loss: 0.7593 - val_accuracy: 0.8917
# Epoch 23/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 0.9946
# Epoch 00023: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-23-0.6164-0.8925.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0261 - accuracy: 0.9946 - val_loss: 0.6164 - val_accuracy: 0.8925
# Epoch 24/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9925
# Epoch 00024: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-24-0.6231-0.9007.h5
# 929/929 [==============================] - 298s 321ms/step - loss: 0.0298 - accuracy: 0.9925 - val_loss: 0.6231 - val_accuracy: 0.9007
# Epoch 25/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9965
# Epoch 00025: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-25-0.6038-0.9057.h5
# 929/929 [==============================] - 296s 319ms/step - loss: 0.0226 - accuracy: 0.9962 - val_loss: 0.6038 - val_accuracy: 0.9057
# Epoch 26/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0275 - accuracy: 0.9933
# Epoch 00026: saving model to ./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-26-0.5952-0.8876.h5
# 929/929 [==============================] - 298s 321ms/step - loss: 0.0275 - accuracy: 0.9933 - val_loss: 0.5952 - val_accuracy: 0.8876

# %%
model.evaluate(test_ds)
# Out:
# 413/413 [==============================] - 64s 154ms/step - loss: 0.5653 - accuracy: 0.8898
# [0.5652635583234613, 0.8898305]

# %% [markdown]
# model.load_weights('./fine_tune_DenseNet121_mel/checkpoint_fine-tuning_dataAgumation/model-19-0.6392-0.8999.h5')
# model.evaluate(test_ds)

# %% [markdown]
# model.load_weights('./fine_tune_DenseNet121_mel/checkpoint_fine-tuning_dataAgumation/model-05-0.3029-0.8843.h5')
# model.evaluate(test_ds)

# %%
model.load_weights('./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-16-0.5768-0.9073.h5')
model.evaluate(test_ds)
# Out:
# 413/413 [==============================] - 63s 152ms/step - loss: 0.6194 - accuracy: 0.8971
# [0.6194461326432791, 0.8970944]

# %%
model.load_weights('./fine_tune_ResNet50_mel/checkpoint_fine-tuning_dataAgumation/model-25-0.6038-0.9057.h5')
model.evaluate(test_ds)
# Out:
# 413/413 [==============================] - 63s 152ms/step - loss: 0.6339 - accuracy: 0.9031
# [0.6339028913721658, 0.9031477]
