# %%
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf
from tensorflow.keras import layers
print(tf.__version__)
print(tf.test.is_gpu_available())

import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2.0.0
# True
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/suzi/anaconda3/envs/tf2/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# # config

# %%
data_path = '/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform'
train_path = data_path + '/train/*/*'
test_path = data_path + '/test/*/*'
val_path = data_path + '/validation/*/*'

class_names = ['sick', 'not_sick']
img_height = 227#227
img_width = 227#227
batch_size = 4
train_samples = 1434 + 2282
steps_per_epoch = train_samples // batch_size
steps_per_epoch
# Out:
# 929

# %% [markdown]
# # get dataset

# %%
def decode_str_tensor(tensor):
    return bytes.decode(tensor.numpy())

def stats(t):
    s = 'mean:'
    s += str(t.mean())
    s += ' max:'
    s += str(t.max())
    s += ' min:'
    s += str(t.min())
    s += ' median:'
    s += str(np.median(t))
    s += ' std:'
    s += str(t.std())
    s += ' shape:'
    s += str(t.shape)
    s += ' dtype:'
    s += str(t.dtype)
    print(s)

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    one_hot = parts[-2] == class_names
    one_hot = tf.cast(one_hot, tf.int64)
    # Integer encode the label
    return tf.argmax(one_hot)
get_label('/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform/train/sick/audioset_0CroKP1sYVw_10_15.jpg')
# Out:
# <tf.Tensor: id=67, shape=(), dtype=int64, numpy=0>

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)
    # resize the image to the desired size
    img = tf.image.resize(img, [img_height, img_width])
#     img = img/127.5 - 1
    return img, label
img, label = process_path('/media/suzi/Seagate Expansion Drive/cough_task_for_job/data/continuous_wavelet_transform/continuous_wavelet_transform/train/sick/audioset_0CroKP1sYVw_10_15.jpg')
stats(img.numpy())
# Out:
# mean:47.180405 max:255.0 min:0.0 median:1.0 std:65.353775 shape:(227, 227, 3) dtype:float32

# %%
def get_dataset(path):
    ds = tf.data.Dataset.list_files(path)
    ds = ds.map(process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = ds.cache().shuffle(buffer_size=100).batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return ds

train_ds = get_dataset(train_path)
test_ds = get_dataset(test_path)
val_ds = get_dataset(val_path)
train_ds
# Out:
# <DatasetV1Adapter shapes: ((None, 227, 227, 3), (None,)), types: (tf.float32, tf.int64)>

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (4, 227, 227, 3)
# Label:  [0 1 1 1]

# %%
image_batch, label_batch = next(iter(val_ds))

plt.figure(figsize=(10, 10))
for i in range(4):
  ax = plt.subplot(2, 2, i + 1)
  plt.imshow((image_batch[i].numpy()).astype("uint8"))
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# # model

# %% [markdown]
# ### Feature extraction

# %%
IMG_SHAPE = (img_height, img_width, 3)
base_model = tf.keras.applications.DenseNet121(include_top=False, 
                                               weights='imagenet', 
                                               input_shape=IMG_SHAPE
)
# base_model = tf.keras.applications.ResNet50(include_top=False, 
#                                             weights='imagenet', 
#                                             input_shape=IMG_SHAPE,
#                                             classes=1)
base_model.trainable = False
base_model.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 227, 227, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 233, 233, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 114, 114, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 114, 114, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 114, 114, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 116, 116, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 57, 57, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 57, 57, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 57, 57, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 57, 57, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 57, 57, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 57, 57, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 57, 57, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 57, 57, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 57, 57, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 57, 57, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 57, 57, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 57, 57, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 57, 57, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 57, 57, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 57, 57, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 57, 57, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 57, 57, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 57, 57, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 57, 57, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 57, 57, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 57, 57, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 57, 57, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 57, 57, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 57, 57, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 57, 57, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 57, 57, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 57, 57, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 57, 57, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 57, 57, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 57, 57, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 57, 57, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 57, 57, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 57, 57, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 57, 57, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 57, 57, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 57, 57, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 57, 57, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 57, 57, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 57, 57, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 57, 57, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 57, 57, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 57, 57, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 57, 57, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 57, 57, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 57, 57, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 57, 57, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 28, 28, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 28, 28, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 28, 28, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 28, 28, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 28, 28, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 28, 28, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 28, 28, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 28, 28, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 28, 28, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 28, 28, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 28, 28, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 28, 28, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 28, 28, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 28, 28, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 28, 28, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 28, 28, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 28, 28, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 28, 28, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 28, 28, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 28, 28, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 28, 28, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 28, 28, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 28, 28, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 28, 28, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 28, 28, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 28, 28, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 28, 28, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 28, 28, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 28, 28, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 28, 28, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 28, 28, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 28, 28, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 28, 28, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 28, 28, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 28, 28, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 28, 28, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 28, 28, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 28, 28, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 28, 28, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 28, 28, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 28, 28, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 28, 28, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 28, 28, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 14, 14, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 14, 14, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 14, 14, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 14, 14, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 14, 14, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 14, 14, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 14, 14, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 14, 14, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 14, 14, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 14, 14, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 14, 14, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 14, 14, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 14, 14, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 14, 14, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 14, 14, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 14, 14, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 14, 14, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 14, 14, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 14, 14, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 14, 14, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 14, 14, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 14, 14, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 14, 14, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 14, 14, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 14, 14, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 14, 14, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 14, 14, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 14, 14, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 14, 14, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 14, 14, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 14, 14, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 14, 14, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 14, 14, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 14, 14, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 14, 14, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 14, 14, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 14, 14, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 14, 14, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 14, 14, 640)  2560        conv4_block12_concat[0][0]
# ...
# conv5_block6_2_conv (Conv2D)    (None, 7, 7, 32)     36864       conv5_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block6_concat (Concatenat (None, 7, 7, 704)    0           conv5_block5_concat[0][0]
#                                                                  conv5_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block7_0_bn (BatchNormali (None, 7, 7, 704)    2816        conv5_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block7_0_relu (Activation (None, 7, 7, 704)    0           conv5_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_conv (Conv2D)    (None, 7, 7, 128)    90112       conv5_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_bn (BatchNormali (None, 7, 7, 128)    512         conv5_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_relu (Activation (None, 7, 7, 128)    0           conv5_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_2_conv (Conv2D)    (None, 7, 7, 32)     36864       conv5_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_concat (Concatenat (None, 7, 7, 736)    0           conv5_block6_concat[0][0]
#                                                                  conv5_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_bn (BatchNormali (None, 7, 7, 736)    2944        conv5_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_relu (Activation (None, 7, 7, 736)    0           conv5_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_conv (Conv2D)    (None, 7, 7, 128)    94208       conv5_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_bn (BatchNormali (None, 7, 7, 128)    512         conv5_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_relu (Activation (None, 7, 7, 128)    0           conv5_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_2_conv (Conv2D)    (None, 7, 7, 32)     36864       conv5_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_concat (Concatenat (None, 7, 7, 768)    0           conv5_block7_concat[0][0]
#                                                                  conv5_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_bn (BatchNormali (None, 7, 7, 768)    3072        conv5_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_relu (Activation (None, 7, 7, 768)    0           conv5_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_conv (Conv2D)    (None, 7, 7, 128)    98304       conv5_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_bn (BatchNormali (None, 7, 7, 128)    512         conv5_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_relu (Activation (None, 7, 7, 128)    0           conv5_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_2_conv (Conv2D)    (None, 7, 7, 32)     36864       conv5_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_concat (Concatenat (None, 7, 7, 800)    0           conv5_block8_concat[0][0]
#                                                                  conv5_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_bn (BatchNormal (None, 7, 7, 800)    3200        conv5_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_relu (Activatio (None, 7, 7, 800)    0           conv5_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_conv (Conv2D)   (None, 7, 7, 128)    102400      conv5_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_concat (Concatena (None, 7, 7, 832)    0           conv5_block9_concat[0][0]
#                                                                  conv5_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_bn (BatchNormal (None, 7, 7, 832)    3328        conv5_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_relu (Activatio (None, 7, 7, 832)    0           conv5_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_conv (Conv2D)   (None, 7, 7, 128)    106496      conv5_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_concat (Concatena (None, 7, 7, 864)    0           conv5_block10_concat[0][0]
#                                                                  conv5_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_bn (BatchNormal (None, 7, 7, 864)    3456        conv5_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_relu (Activatio (None, 7, 7, 864)    0           conv5_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_conv (Conv2D)   (None, 7, 7, 128)    110592      conv5_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_concat (Concatena (None, 7, 7, 896)    0           conv5_block11_concat[0][0]
#                                                                  conv5_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_bn (BatchNormal (None, 7, 7, 896)    3584        conv5_block12_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_relu (Activatio (None, 7, 7, 896)    0           conv5_block13_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_conv (Conv2D)   (None, 7, 7, 128)    114688      conv5_block13_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_concat (Concatena (None, 7, 7, 928)    0           conv5_block12_concat[0][0]
#                                                                  conv5_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_bn (BatchNormal (None, 7, 7, 928)    3712        conv5_block13_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_relu (Activatio (None, 7, 7, 928)    0           conv5_block14_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_conv (Conv2D)   (None, 7, 7, 128)    118784      conv5_block14_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_concat (Concatena (None, 7, 7, 960)    0           conv5_block13_concat[0][0]
#                                                                  conv5_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_bn (BatchNormal (None, 7, 7, 960)    3840        conv5_block14_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_relu (Activatio (None, 7, 7, 960)    0           conv5_block15_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_conv (Conv2D)   (None, 7, 7, 128)    122880      conv5_block15_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_concat (Concatena (None, 7, 7, 992)    0           conv5_block14_concat[0][0]
#                                                                  conv5_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_bn (BatchNormal (None, 7, 7, 992)    3968        conv5_block15_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_relu (Activatio (None, 7, 7, 992)    0           conv5_block16_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_conv (Conv2D)   (None, 7, 7, 128)    126976      conv5_block16_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block16_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block16_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block16_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_concat (Concatena (None, 7, 7, 1024)   0           conv5_block15_concat[0][0]
#                                                                  conv5_block16_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 7, 7, 1024)   4096        conv5_block16_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 7, 7, 1024)   0           bn[0][0]
# ==================================================================================================
# Total params: 7,037,504
# Trainable params: 0
# Non-trainable params: 7,037,504
# __________________________________________________________________________________________________

# %%
inputs = tf.keras.Input(shape=IMG_SHAPE)
x = tf.keras.applications.densenet.preprocess_input(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
# x = layers.Dropout(0.5)(x)
# x = layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_truediv (TensorF [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_truediv_1 (Tenso [(None, 227, 227, 3)]     0
# _________________________________________________________________
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1025
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
base_learning_rate = 0.0001
save_dir = './fine_tune_DenseNet121_cwt/'
log_dir = save_dir + 'logs/'
checkpoint_dir = save_dir + 'checkpoint/'

lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    base_learning_rate,
    decay_steps=steps_per_epoch*5,
    decay_rate=1,
    staircase=False)

optimizer = tf.keras.optimizers.Adam(lr_schedule)

callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10),
        tf.keras.callbacks.TensorBoard(log_dir),
        tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_dir,
                                            monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                            save_weights_only=True)
    ]

# %%
initial_epochs = 100

model.compile(optimizer=optimizer,
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_ds,
                    epochs=initial_epochs,
                    validation_data=val_ds,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
#       1/Unknown - 6s 6s/step - loss: 1.0108 - accuracy: 0.5000WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.102884). Check your callbacks.
#     929/Unknown - 27s 29ms/step - loss: 0.7305 - accuracy: 0.5751
# Epoch 00001: val_accuracy improved from -inf to 0.70221, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 37s 39ms/step - loss: 0.7305 - accuracy: 0.5751 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.6532 - accuracy: 0.6309
# Epoch 00002: val_accuracy improved from 0.70221 to 0.71370, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.6532 - accuracy: 0.6305 - val_loss: 0.5430 - val_accuracy: 0.7137
# Epoch 3/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.6200 - accuracy: 0.6553
# Epoch 00003: val_accuracy did not improve from 0.71370
# 929/929 [==============================] - 27s 29ms/step - loss: 0.6201 - accuracy: 0.6553 - val_loss: 0.5261 - val_accuracy: 0.7121
# Epoch 4/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5967 - accuracy: 0.6690
# Epoch 00004: val_accuracy did not improve from 0.71370
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5963 - accuracy: 0.6693 - val_loss: 0.5166 - val_accuracy: 0.7121
# Epoch 5/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5970 - accuracy: 0.6775
# Epoch 00005: val_accuracy improved from 0.71370 to 0.71780, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5970 - accuracy: 0.6773 - val_loss: 0.5104 - val_accuracy: 0.7178
# Epoch 6/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5807 - accuracy: 0.6832
# Epoch 00006: val_accuracy did not improve from 0.71780
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5807 - accuracy: 0.6830 - val_loss: 0.5047 - val_accuracy: 0.7162
# Epoch 7/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5602 - accuracy: 0.7019
# Epoch 00007: val_accuracy improved from 0.71780 to 0.72108, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5601 - accuracy: 0.7021 - val_loss: 0.5009 - val_accuracy: 0.7211
# Epoch 8/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5592 - accuracy: 0.6974
# Epoch 00008: val_accuracy improved from 0.72108 to 0.72190, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 31ms/step - loss: 0.5597 - accuracy: 0.6973 - val_loss: 0.4979 - val_accuracy: 0.7219
# Epoch 9/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5620 - accuracy: 0.6864 E
# Epoch 00009: val_accuracy improved from 0.72190 to 0.72354, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5624 - accuracy: 0.6865 - val_loss: 0.4953 - val_accuracy: 0.7235
# Epoch 10/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5520 - accuracy: 0.7052
# Epoch 00010: val_accuracy improved from 0.72354 to 0.72518, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5518 - accuracy: 0.7056 - val_loss: 0.4933 - val_accuracy: 0.7252
# Epoch 11/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5560 - accuracy: 0.7052
# Epoch 00011: val_accuracy did not improve from 0.72518
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5561 - accuracy: 0.7051 - val_loss: 0.4916 - val_accuracy: 0.7219
# Epoch 12/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5403 - accuracy: 0.7103
# Epoch 00012: val_accuracy improved from 0.72518 to 0.73011, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5407 - accuracy: 0.7096 - val_loss: 0.4902 - val_accuracy: 0.7301
# Epoch 13/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5470 - accuracy: 0.7036
# Epoch 00013: val_accuracy improved from 0.73011 to 0.73421, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5471 - accuracy: 0.7034 - val_loss: 0.4884 - val_accuracy: 0.7342
# Epoch 14/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5433 - accuracy: 0.7030
# Epoch 00014: val_accuracy did not improve from 0.73421
# 929/929 [==============================] - 27s 30ms/step - loss: 0.5428 - accuracy: 0.7037 - val_loss: 0.4872 - val_accuracy: 0.7260
# Epoch 15/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5340 - accuracy: 0.7114
# Epoch 00015: val_accuracy did not improve from 0.73421
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5335 - accuracy: 0.7121 - val_loss: 0.4856 - val_accuracy: 0.7285
# Epoch 16/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.7130 ETA: 1s -
# Epoch 00016: val_accuracy improved from 0.73421 to 0.73913, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5351 - accuracy: 0.7129 - val_loss: 0.4848 - val_accuracy: 0.7391
# Epoch 17/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7085
# Epoch 00017: val_accuracy did not improve from 0.73913
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5368 - accuracy: 0.7086 - val_loss: 0.4838 - val_accuracy: 0.7375
# Epoch 18/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5338 - accuracy: 0.7092
# Epoch 00018: val_accuracy improved from 0.73913 to 0.74077, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5334 - accuracy: 0.7096 - val_loss: 0.4830 - val_accuracy: 0.7408
# Epoch 19/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5317 - accuracy: 0.7176
# Epoch 00019: val_accuracy did not improve from 0.74077
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5321 - accuracy: 0.7172 - val_loss: 0.4826 - val_accuracy: 0.7383
# Epoch 20/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5315 - accuracy: 0.7107
# Epoch 00020: val_accuracy did not improve from 0.74077
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5315 - accuracy: 0.7110 - val_loss: 0.4814 - val_accuracy: 0.7375
# Epoch 21/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5238 - accuracy: 0.7247
# Epoch 00021: val_accuracy did not improve from 0.74077
# 929/929 [==============================] - 27s 30ms/step - loss: 0.5238 - accuracy: 0.7250 - val_loss: 0.4809 - val_accuracy: 0.7391
# Epoch 22/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5310 - accuracy: 0.7122
# Epoch 00022: val_accuracy did not improve from 0.74077
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5308 - accuracy: 0.7123 - val_loss: 0.4803 - val_accuracy: 0.7391
# Epoch 23/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5299 - accuracy: 0.7130
# Epoch 00023: val_accuracy improved from 0.74077 to 0.74323, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5302 - accuracy: 0.7131 - val_loss: 0.4796 - val_accuracy: 0.7432
# Epoch 24/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5237 - accuracy: 0.7228
# Epoch 00024: val_accuracy improved from 0.74323 to 0.74405, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5237 - accuracy: 0.7231 - val_loss: 0.4791 - val_accuracy: 0.7441
# Epoch 25/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5220 - accuracy: 0.7214
# Epoch 00025: val_accuracy did not improve from 0.74405
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5218 - accuracy: 0.7217 - val_loss: 0.4788 - val_accuracy: 0.7408
# Epoch 26/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5287 - accuracy: 0.7206
# Epoch 00026: val_accuracy improved from 0.74405 to 0.74651, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 31ms/step - loss: 0.5282 - accuracy: 0.7212 - val_loss: 0.4785 - val_accuracy: 0.7465
# Epoch 27/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5220 - accuracy: 0.7187 ETA: 0s - loss: 0
# Epoch 00027: val_accuracy did not improve from 0.74651
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5219 - accuracy: 0.7191 - val_loss: 0.4781 - val_accuracy: 0.7465
# Epoch 28/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5181 - accuracy: 0.7306
# Epoch 00028: val_accuracy did not improve from 0.74651
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5176 - accuracy: 0.7312 - val_loss: 0.4776 - val_accuracy: 0.7457
# Epoch 29/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5157 - accuracy: 0.7311
# Epoch 00029: val_accuracy did not improve from 0.74651
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5155 - accuracy: 0.7312 - val_loss: 0.4774 - val_accuracy: 0.7465
# Epoch 30/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5167 - accuracy: 0.7187
# Epoch 00030: val_accuracy improved from 0.74651 to 0.74733, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5167 - accuracy: 0.7185 - val_loss: 0.4767 - val_accuracy: 0.7473
# Epoch 31/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5167 - accuracy: 0.7260
# Epoch 00031: val_accuracy did not improve from 0.74733
# 929/929 [==============================] - 28s 31ms/step - loss: 0.5165 - accuracy: 0.7266 - val_loss: 0.4762 - val_accuracy: 0.7473
# Epoch 32/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5153 - accuracy: 0.7287
# Epoch 00032: val_accuracy did not improve from 0.74733
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5150 - accuracy: 0.7287 - val_loss: 0.4759 - val_accuracy: 0.7473
# Epoch 33/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5124 - accuracy: 0.7295
# Epoch 00033: val_accuracy did not improve from 0.74733
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5127 - accuracy: 0.7295 - val_loss: 0.4756 - val_accuracy: 0.7457
# Epoch 34/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5146 - accuracy: 0.7279
# Epoch 00034: val_accuracy did not improve from 0.74733
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5143 - accuracy: 0.7282 - val_loss: 0.4756 - val_accuracy: 0.7449
# Epoch 35/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5112 - accuracy: 0.7274
# Epoch 00035: val_accuracy improved from 0.74733 to 0.74815, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 31ms/step - loss: 0.5112 - accuracy: 0.7271 - val_loss: 0.4750 - val_accuracy: 0.7482
# Epoch 36/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5190 - accuracy: 0.7284 ETA: 0s - loss: 0.5176 - accu
# Epoch 00036: val_accuracy improved from 0.74815 to 0.74979, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5190 - accuracy: 0.7285 - val_loss: 0.4747 - val_accuracy: 0.7498
# Epoch 37/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5169 - accuracy: 0.7238
# Epoch 00037: val_accuracy improved from 0.74979 to 0.75062, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5166 - accuracy: 0.7239 - val_loss: 0.4746 - val_accuracy: 0.7506
# Epoch 38/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5145 - accuracy: 0.7257
# Epoch 00038: val_accuracy did not improve from 0.75062
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5147 - accuracy: 0.7258 - val_loss: 0.4743 - val_accuracy: 0.7506
# Epoch 39/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5111 - accuracy: 0.7311
# Epoch 00039: val_accuracy did not improve from 0.75062
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5111 - accuracy: 0.7312 - val_loss: 0.4741 - val_accuracy: 0.7506
# Epoch 40/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5211 - accuracy: 0.7195
# Epoch 00040: val_accuracy did not improve from 0.75062
# 929/929 [==============================] - 27s 29ms/step - loss: 0.5214 - accuracy: 0.7196 - val_loss: 0.4738 - val_accuracy: 0.7506
# Epoch 41/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5091 - accuracy: 0.7266
# Epoch 00041: val_accuracy did not improve from 0.75062
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5091 - accuracy: 0.7269 - val_loss: 0.4735 - val_accuracy: 0.7506
# Epoch 42/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5120 - accuracy: 0.7217
# Epoch 00042: val_accuracy improved from 0.75062 to 0.75144, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5119 - accuracy: 0.7223 - val_loss: 0.4735 - val_accuracy: 0.7514
# Epoch 43/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5097 - accuracy: 0.7298
# Epoch 00043: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5097 - accuracy: 0.7298 - val_loss: 0.4735 - val_accuracy: 0.7506
# Epoch 44/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5172 - accuracy: 0.7279
# Epoch 00044: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5169 - accuracy: 0.7282 - val_loss: 0.4731 - val_accuracy: 0.7506
# Epoch 45/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5069 - accuracy: 0.7389
# Epoch 00045: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5067 - accuracy: 0.7384 - val_loss: 0.4730 - val_accuracy: 0.7506
# Epoch 46/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5113 - accuracy: 0.7266
# Epoch 00046: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5113 - accuracy: 0.7269 - val_loss: 0.4729 - val_accuracy: 0.7514
# Epoch 47/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5091 - accuracy: 0.7343
# Epoch 00047: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 27s 30ms/step - loss: 0.5090 - accuracy: 0.7347 - val_loss: 0.4728 - val_accuracy: 0.7506
# Epoch 48/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5135 - accuracy: 0.7244
# Epoch 00048: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5137 - accuracy: 0.7247 - val_loss: 0.4727 - val_accuracy: 0.7506
# Epoch 49/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5032 - accuracy: 0.7398
# Epoch 00049: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5033 - accuracy: 0.7395 - val_loss: 0.4725 - val_accuracy: 0.7514
# Epoch 50/100
# 926/929 [============================>.] - ETA: 0s - loss: 0.5134 - accuracy: 0.7214
# Epoch 00050: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 27s 30ms/step - loss: 0.5132 - accuracy: 0.7223 - val_loss: 0.4726 - val_accuracy: 0.7514
# Epoch 51/100
# 927/929 [============================>.] - ETA: 0s - loss: 0.5077 - accuracy: 0.7317
# Epoch 00051: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5081 - accuracy: 0.7309 - val_loss: 0.4719 - val_accuracy: 0.7506
# Epoch 52/100
# 928/929 [============================>.] - ETA: 0s - loss: 0.5099 - accuracy: 0.7287
# Epoch 00052: val_accuracy did not improve from 0.75144
# 929/929 [==============================] - 28s 30ms/step - loss: 0.5099 - accuracy: 0.7287 - val_loss: 0.4720 - val_accuracy: 0.7514

# %%
model.load_weights(checkpoint_dir)
model.evaluate(test_ds)
# Out:
# 413/413 [==============================] - 10s 25ms/step - loss: 0.4881 - accuracy: 0.7409
# [0.48805508086092536, 0.7409201]

# %% [markdown]
# ### fine tuning

# %%
base_model.trainable = True
print("Number of layers in the base model: ", len(base_model.layers))

# # Fine-tune from this layer onwards
# fine_tune_at = 100

# # Freeze all the layers before the `fine_tune_at` layer
# for layer in base_model.layers[:fine_tune_at]:
#     layer.trainable =  False

model.summary()
# Out:
# Number of layers in the base model:  427
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_truediv (TensorF [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_BiasAdd (TensorF [(None, 227, 227, 3)]     0
# _________________________________________________________________
# tf_op_layer_truediv_1 (Tenso [(None, 227, 227, 3)]     0
# _________________________________________________________________
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1025
# =================================================================
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Total params: 84,673
# Trainable params: 1,025
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
fine_tune_epochs = 100 + initial_epochs

lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    base_learning_rate/10,
    decay_steps=steps_per_epoch*5,
    decay_rate=1,
    staircase=False)
optimizer = tf.keras.optimizers.Adam(lr_schedule)

model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = optimizer,
              metrics=['accuracy'])

history_fine = model.fit(train_ds,
                         epochs=fine_tune_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=val_ds,
                         callbacks=callbacks)
# Out:
# Epoch 52/200
#     929/Unknown - 76s 82ms/step - loss: 0.4647 - accuracy: 0.7705
# Epoch 00052: val_accuracy improved from 0.75144 to 0.83921, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 86s 92ms/step - loss: 0.4647 - accuracy: 0.7705 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 53/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.3678 - accuracy: 0.8311
# Epoch 00053: val_accuracy improved from 0.83921 to 0.84906, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 74s 80ms/step - loss: 0.3678 - accuracy: 0.8313 - val_loss: 0.3536 - val_accuracy: 0.8491
# Epoch 54/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.2967 - accuracy: 0.8693
# Epoch 00054: val_accuracy did not improve from 0.84906
# 929/929 [==============================] - 74s 80ms/step - loss: 0.2967 - accuracy: 0.8695 - val_loss: 0.3631 - val_accuracy: 0.8228
# Epoch 55/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.2450 - accuracy: 0.8971
# Epoch 00055: val_accuracy did not improve from 0.84906
# 929/929 [==============================] - 74s 80ms/step - loss: 0.2450 - accuracy: 0.8972 - val_loss: 0.3284 - val_accuracy: 0.8482
# Epoch 56/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.2004 - accuracy: 0.9213
# Epoch 00056: val_accuracy improved from 0.84906 to 0.85644, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 76s 82ms/step - loss: 0.2004 - accuracy: 0.9214 - val_loss: 0.3603 - val_accuracy: 0.8564
# Epoch 57/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1484 - accuracy: 0.9432
# Epoch 00057: val_accuracy improved from 0.85644 to 0.86136, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 77s 83ms/step - loss: 0.1484 - accuracy: 0.9432 - val_loss: 0.3755 - val_accuracy: 0.8614
# Epoch 58/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1183 - accuracy: 0.9558
# Epoch 00058: val_accuracy did not improve from 0.86136
# 929/929 [==============================] - 77s 83ms/step - loss: 0.1183 - accuracy: 0.9559 - val_loss: 0.4179 - val_accuracy: 0.8573
# Epoch 59/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9658
# Epoch 00059: val_accuracy improved from 0.86136 to 0.86300, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 79s 85ms/step - loss: 0.1033 - accuracy: 0.9658 - val_loss: 0.4345 - val_accuracy: 0.8630
# Epoch 60/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9790
# Epoch 00060: val_accuracy did not improve from 0.86300
# 929/929 [==============================] - 80s 86ms/step - loss: 0.0697 - accuracy: 0.9790 - val_loss: 0.5226 - val_accuracy: 0.8556
# Epoch 61/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0512 - accuracy: 0.9846
# Epoch 00061: val_accuracy did not improve from 0.86300
# 929/929 [==============================] - 79s 85ms/step - loss: 0.0512 - accuracy: 0.9847 - val_loss: 0.7451 - val_accuracy: 0.8359
# Epoch 62/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9876
# Epoch 00062: val_accuracy did not improve from 0.86300
# 929/929 [==============================] - 81s 87ms/step - loss: 0.0414 - accuracy: 0.9876 - val_loss: 0.7125 - val_accuracy: 0.8499
# Epoch 63/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0375 - accuracy: 0.9890
# Epoch 00063: val_accuracy improved from 0.86300 to 0.86546, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 80s 86ms/step - loss: 0.0375 - accuracy: 0.9890 - val_loss: 0.6267 - val_accuracy: 0.8655
# Epoch 64/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9916
# Epoch 00064: val_accuracy did not improve from 0.86546
# 929/929 [==============================] - 81s 88ms/step - loss: 0.0324 - accuracy: 0.9917 - val_loss: 0.9361 - val_accuracy: 0.8384
# Epoch 65/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9933
# Epoch 00065: val_accuracy improved from 0.86546 to 0.86874, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 80s 87ms/step - loss: 0.0309 - accuracy: 0.9933 - val_loss: 0.7611 - val_accuracy: 0.8687
# Epoch 66/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0194 - accuracy: 0.9962
# Epoch 00066: val_accuracy did not improve from 0.86874
# 929/929 [==============================] - 80s 86ms/step - loss: 0.0194 - accuracy: 0.9962 - val_loss: 0.8668 - val_accuracy: 0.8679
# Epoch 67/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9938
# Epoch 00067: val_accuracy did not improve from 0.86874
# 929/929 [==============================] - 81s 88ms/step - loss: 0.0278 - accuracy: 0.9938 - val_loss: 0.8323 - val_accuracy: 0.8646
# Epoch 68/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0235 - accuracy: 0.9957
# Epoch 00068: val_accuracy did not improve from 0.86874
# 929/929 [==============================] - 80s 86ms/step - loss: 0.0235 - accuracy: 0.9957 - val_loss: 0.8075 - val_accuracy: 0.8573
# Epoch 69/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9976
# Epoch 00069: val_accuracy did not improve from 0.86874
# 929/929 [==============================] - 82s 89ms/step - loss: 0.0169 - accuracy: 0.9973 - val_loss: 1.0589 - val_accuracy: 0.8458
# Epoch 70/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 0.9973
# Epoch 00070: val_accuracy did not improve from 0.86874
# 929/929 [==============================] - 81s 88ms/step - loss: 0.0158 - accuracy: 0.9973 - val_loss: 0.8318 - val_accuracy: 0.8671
# Epoch 71/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9987
# Epoch 00071: val_accuracy did not improve from 0.86874
# 929/929 [==============================] - 81s 87ms/step - loss: 0.0135 - accuracy: 0.9987 - val_loss: 0.9750 - val_accuracy: 0.8605
# Epoch 72/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0203 - accuracy: 0.9968
# Epoch 00072: val_accuracy did not improve from 0.86874
# 929/929 [==============================] - 79s 85ms/step - loss: 0.0203 - accuracy: 0.9968 - val_loss: 0.9681 - val_accuracy: 0.8638
# Epoch 73/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9957
# Epoch 00073: val_accuracy improved from 0.86874 to 0.87121, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 82s 89ms/step - loss: 0.0225 - accuracy: 0.9957 - val_loss: 0.9052 - val_accuracy: 0.8712
# Epoch 74/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.9978
# Epoch 00074: val_accuracy improved from 0.87121 to 0.87203, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 83s 89ms/step - loss: 0.0157 - accuracy: 0.9978 - val_loss: 0.8510 - val_accuracy: 0.8720
# Epoch 75/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9987
# Epoch 00075: val_accuracy improved from 0.87203 to 0.87367, saving model to ./fine_tune_DenseNet121_cwt/checkpoint/
# 929/929 [==============================] - 81s 87ms/step - loss: 0.0124 - accuracy: 0.9987 - val_loss: 0.9088 - val_accuracy: 0.8737
# Epoch 76/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9992
# Epoch 00076: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 80s 86ms/step - loss: 0.0114 - accuracy: 0.9992 - val_loss: 1.0260 - val_accuracy: 0.8671
# Epoch 77/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9995
# Epoch 00077: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 82s 88ms/step - loss: 0.0101 - accuracy: 0.9992 - val_loss: 1.1377 - val_accuracy: 0.8712
# Epoch 78/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9976
# Epoch 00078: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 80s 86ms/step - loss: 0.0149 - accuracy: 0.9976 - val_loss: 0.9483 - val_accuracy: 0.8696
# Epoch 79/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9984
# Epoch 00079: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 80s 86ms/step - loss: 0.0122 - accuracy: 0.9984 - val_loss: 0.9859 - val_accuracy: 0.8737
# Epoch 80/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9992
# Epoch 00080: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 81s 87ms/step - loss: 0.0105 - accuracy: 0.9992 - val_loss: 1.0464 - val_accuracy: 0.8704
# Epoch 81/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9981
# Epoch 00081: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 79s 85ms/step - loss: 0.0125 - accuracy: 0.9981 - val_loss: 1.0432 - val_accuracy: 0.8679
# Epoch 82/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9992
# Epoch 00082: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 79s 85ms/step - loss: 0.0106 - accuracy: 0.9992 - val_loss: 1.0937 - val_accuracy: 0.8687
# Epoch 83/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9992
# Epoch 00083: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 80s 86ms/step - loss: 0.0101 - accuracy: 0.9992 - val_loss: 1.0477 - val_accuracy: 0.8704
# Epoch 84/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9995
# Epoch 00084: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 81s 87ms/step - loss: 0.0103 - accuracy: 0.9995 - val_loss: 1.1156 - val_accuracy: 0.8696
# Epoch 85/200
# 928/929 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 0.9995
# Epoch 00085: val_accuracy did not improve from 0.87367
# 929/929 [==============================] - 79s 85ms/step - loss: 0.0096 - accuracy: 0.9995 - val_loss: 1.1945 - val_accuracy: 0.8671

# %%
model.load_weights(checkpoint_dir)
model.evaluate(test_ds)
# Out:
# 413/413 [==============================] - 9s 22ms/step - loss: 0.9166 - accuracy: 0.8614
# [0.9165911908525315, 0.86138016]
